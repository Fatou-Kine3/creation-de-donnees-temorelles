# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43

print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43

print("Thickness: {:.2f} kilometers".format(folded_thickness / 1000))
# Out:
# Thickness: 703687.44 kilometers

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS

for i in range(43):
    folded_thickness = folded_thickness * 2

print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %%
from time import perf_counter

THICKNESS = 0.00008

# Method 1: exponentiation
start = perf_counter()
folded_thickness = THICKNESS * 2 ** 43
elapsed_time = perf_counter() - start
print("Method 1 time : {}[s]".format(elapsed_time))

# Method 2: for statement
start = perf_counter()
folded_thickness = THICKNESS

for i in range(43):
    folded_thickness = folded_thickness * 2

elapsed_time = perf_counter() - start
print("Method 2 time : {}[s]".format(elapsed_time))
# Out:
# Method 1 time : 0.00012225000000398722[s]
# Method 2 time : 0.00017804200001592108[s]

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS
thickness = []

for i in range(44):
    thickness.append(folded_thickness)
    folded_thickness = folded_thickness * 2

# %%
import matplotlib.pyplot as plt

folded_times = list(range(44))

plt.plot(folded_times, thickness)

plt.xlabel("Number of folds")
plt.ylabel("Thickness (m)")
plt.title("Thickness of paper after folding")

plt.show()

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS

thickness = []

thickness.append(folded_thickness)

for i in range(43):
    folded_thickness = folded_thickness * 2
    thickness.append(folded_thickness)

print(len(thickness))
# Out:
# 44

# %%
import matplotlib.pyplot as plt

THICKNESS = 0.00008

folded_thickness = THICKNESS
thickness = []

thickness.append(folded_thickness)

for i in range(43):
    folded_thickness = folded_thickness * 2
    thickness.append(folded_thickness)

print(len(thickness))

# Display the graph
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(thickness)
plt.show()
# Out:
# 44

# %%
import matplotlib.pyplot as plt

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")

plt.plot(thickness, color="green", linewidth=3)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")

plt.plot(thickness, color="purple", linestyle=":")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("thickness of folded paper", fontsize=16)
plt.xlabel("number of folds", fontsize=14)
plt.ylabel("thickness [m]", fontsize=14)

plt.tick_params(labelsize=12)

plt.plot(thickness, linewidth=2)

plt.show()

# %%
# =========================
# Problem 1
# =========================

THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43

print("Problem 1")
print("Thickness: {} meters".format(folded_thickness))


# =========================
# Problem 2
# =========================

print("Problem 2")
print("Thickness: {:.2f} kilometers".format(folded_thickness / 1000))


# =========================
# Problem 3
# =========================

folded_thickness = THICKNESS

for i in range(43):
    folded_thickness = folded_thickness * 2

print("Problem 3")
print("Thickness: {} meters".format(folded_thickness))
# Out:
# Problem 1
# Thickness: 703687441.77664 meters
# Problem 2
# Thickness: 703687.44 kilometers
# Problem 3
# Thickness: 703687441.77664 meters

# %%
# =========================
# Problem 4
# =========================

from time import perf_counter

# Method 1: exponentiation
start = perf_counter()

folded_thickness = THICKNESS * 2 ** 43

elapsed_time = perf_counter() - start

print("Problem 4")
print("Method 1 time : {}[s]".format(elapsed_time))


# Method 2: for statement
start = perf_counter()

folded_thickness = THICKNESS

for i in range(43):
    folded_thickness = folded_thickness * 2

elapsed_time = perf_counter() - start

print("Method 2 time : {}[s]".format(elapsed_time))
# Out:
# Problem 4
# Method 1 time : 0.00013520799984689802[s]
# Method 2 time : 0.00013241699980426347[s]

# %%
# =========================
# Problem 5
# =========================

folded_thickness = THICKNESS

thickness = []

thickness.append(folded_thickness)

for i in range(43):
    folded_thickness = folded_thickness * 2
    thickness.append(folded_thickness)

print("Problem 5")
print("Number of values:", len(thickness))
# Out:
# Problem 5
# Number of values: 44

# %%
# =========================
# Problem 6
# =========================

import matplotlib.pyplot as plt

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(thickness)
plt.show()

# %%
# =========================
# Problem 7
# =========================

# Graph 1: Green and thick line
plt.figure()
plt.title("Thickness of folded paper")
plt.xlabel("Number of folds")
plt.ylabel("Thickness [m]")
plt.plot(thickness, color="green", linewidth=3)
plt.show()


# Graph 2: Dotted line
plt.figure()
plt.title("Thickness of folded paper")
plt.xlabel("Number of folds")
plt.ylabel("Thickness [m]")
plt.plot(thickness, color="purple", linestyle=":")
plt.show()


# Graph 3: Larger font
plt.figure()
plt.title("Thickness of folded paper", fontsize=16)
plt.xlabel("Number of folds", fontsize=14)
plt.ylabel("Thickness [m]", fontsize=14)
plt.tick_params(labelsize=12)
plt.plot(thickness)
plt.show()
